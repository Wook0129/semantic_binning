# %%
from experiment import Experiment

# %matplotlib inline
# Out:
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
var_dict = dict(
    numerical_vars = ['A02', 'A05', 'A08', 'A11', 'A13', 'A16', 'A18'],
    categorical_vars = ['A01','A03','A04','A06','A07','A09','A10','A12','A14','A15','A17','A19','A20'],
    class_var = 'class'
)

# %%
exp = Experiment('data/credit2.csv', 
                 var_dict,
                 embedding_dim=8,
                 lr=0.2,
                 cv=5,
                 weight_decay=0.0,
                 batch_size=1024,
                 n_epoch=100,
                 verbose=True,
                 n_bins_range=[3, 5, 10],
                 n_init_bins_list=[5, 10, 15])

# %%
exp.data.shape
# Out:
# (1000, 21)

# %%
list_of_scores = exp.perform_exp()
# Out:
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:819: RuntimeWarning: invalid value encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:819: RuntimeWarning: invalid value encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:819: RuntimeWarning: invalid value encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:819: RuntimeWarning: invalid value encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:819: RuntimeWarning: invalid value encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# 3.4948761463165283 training start
# >>> Epoch = 1
# Loss = 2.2268664836883545
# ...

# %%
result = exp.print_scores(list_of_scores)

# %%
result.sort_values(by='lr_acc_C=0.3', ascending=False)
# Out:
#   disc_method  dt_acc_depth=2  dt_acc_depth=3  dt_acc_depth=4  dt_acc_depth=5  \
# 6        ew_5           0.684           0.706           0.711           0.704
# 0         raw           0.696           0.707           0.714           0.718
# 7        ef_5           0.721           0.723           0.718           0.710
# 9       ef_10           0.703           0.697           0.690           0.718
# 8       ew_10           0.700           0.677           0.686           0.700
# 4        ew_3           0.724           0.730           0.718           0.714
# 2       sb_10           0.691           0.698           0.708           0.709
# 5        ef_3           0.714           0.699           0.700           0.699
# 1        sb_5           0.716           0.706           0.702           0.701
# 3       sb_15           0.691           0.700           0.715           0.701
#
#    dt_acc_depth=6  kmeans_nmi  lr_acc_C=0.1  lr_acc_C=0.3  lr_acc_C=0.5  \
# ...

# %%
from matplotlib import pyplot as plt

def plot_model_comparison_chart(result):
    
    def get_marker_colors(disc_method_list):
        colors = []
        for method in disc_method_list:
            if 'sb' in method:
                colors.append('r')
            if 'ew' in method:
                colors.append('b')
            if 'ef' in method:
                colors.append('g')
        return colors
        
    def get_rel_n_cols(result):
        n_cols = result['n_disc_cols']
        max_n_cols = n_cols.max()
        rel_n_cols = [(x / max_n_cols) for x in n_cols]
        return rel_n_cols
    
    def get_acc(model_name, result):
        if model_name == 'DT':
            acc = result['dt_acc_depth=3']
        if model_name == 'LR':
            acc = result['lr_acc_C=1.0']
        if model_name == 'NB':
            acc = result['nb_acc']
        if model_name == 'RF':
            acc = result['rf_acc_n_est=20']
        if model_name == 'K-means':
            acc = result['kmeans_nmi']
        return list(acc)
    
    def make_plot_for_model(model_name, disc_method, acc, rel_n_cols, loc, fig):        
        ax = fig.add_subplot(loc)
        ax.scatter(x=rel_n_cols, y=acc, s=200, c=get_marker_colors(disc_method))
        for i, xy in enumerate(zip(rel_n_cols, acc)):
            ax.annotate(disc_method[i], xy, fontsize=15)
        ax.set_title(model_name, fontsize=25)
        ax.set_xlabel('Relative Number of Columns', fontsize=25)
        if model_name == 'K-means':
            ax.set_ylabel('NMI', fontsize=20)        
        else:
            ax.set_ylabel('Accuracy', fontsize=20)        
        
    result = result.loc[result['disc_method'] != 'raw'].reset_index(drop=True)
    disc_method = result['disc_method']
    rel_n_cols = get_rel_n_cols(result)
    
    fig = plt.figure(figsize=(20,20))
    for model_name, loc in zip(['DT','LR','NB','K-means'], [221,222,223,224]):
        acc = get_acc(model_name, result)
        make_plot_for_model(model_name, disc_method, acc, rel_n_cols, loc, fig)

# %%
plot_model_comparison_chart(result)

# %%
for var, bins in exp.semantic_binning.bins_by_var.items():
    print(var)
    print(bins['bins'])
# Out:
# A02
# ['(3.999, 24.0]', '(24.0, 72.0]']
# A05
# ['(249.999, 708.95]', '(708.95, 932.0]', '(932.0, 1157.55]', '(1157.55, 1262.0]', '(1262.0, 1365.5]', '(1365.5, 1479.4]', '(1479.4, 1602.65]', '(1602.65, 1906.8]', '(1906.8, 2100.55]', '(2100.55, 2578.0]', '(2578.0, 2852.4]', '(2852.4, 3187.4]', '(3187.4, 3590.0]', '(3590.0, 3972.25]', '(3972.25, 4720.0]', '(4720.0, 5969.95]', '(5969.95, 7179.4]', '(7179.4, 9162.7]', '(9162.7, 18424.0]']
# A08
# ['(0.999, 2.0]', '(2.0, 4.0]']
# A11
# ['(0.999, 2.0]', '(2.0, 4.0]']
# A13
# ['(18.999, 36.0]', '(36.0, 75.0]']
# A16
# ['(0.999, 2.0]', '(2.0, 4.0]']
# A18
# ['(0.999, 1.155]', '(1.155, 2.0]']

# %%
exp.semantic_binning.plot_pairwise_distance_between_bins('A02')

# %%
exp.semantic_binning.plot_pairwise_distance_between_bins('A05')

# %%
exp.semantic_binning.plot_pairwise_distance_between_bins('A08')

# %%
exp.semantic_binning.plot_pairwise_distance_between_bins('A11')

# %%
exp.semantic_binning.plot_pairwise_distance_between_bins('A13')

# %%
exp.semantic_binning.plot_pairwise_distance_between_bins('A16')

# %%
exp.semantic_binning.plot_pairwise_distance_between_bins('A18')
