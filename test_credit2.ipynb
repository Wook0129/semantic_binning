# %%
from experiment import Experiment
# %matplotlib inline
# Out:
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
var_dict = dict(
    numerical_vars = ['A02', 'A05', 'A08', 'A11', 'A13', 'A16', 'A18'],
    categorical_vars = ['A01','A03','A04','A06','A07','A09','A10','A12','A14','A15','A17','A19','A20'],
    class_var = 'class'
)

# %%
exp = Experiment('data/credit2.csv', 
                 var_dict,
                 embedding_dim=16,
                 lr=1e-3,
                 weight_decay=0.0,
                 batch_size=1024,
                 n_epoch=150,
                 verbose=True,
                 n_bins_range=range(2, 21),
                 n_init_bins_list=[10,15,20,25,30])

# %%
exp.data.shape
# Out:
# (1000, 21)

# %%
list_of_scores = exp.perform_exp()
# Out:
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# /home/taewook/anaconda3/lib/python3.6/site-packages/sklearn/naive_bayes.py:838: RuntimeWarning: invalid value encountered in log
#   neg_prob = np.log(1 - np.exp(self.feature_log_prob_))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/taewook/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56     try:
# ---> 57         return getattr(obj, method)(*args, **kwds)
#      58
#
# AttributeError: 'list' object has no attribute 'argmax'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-abf13113707a> in <module>()
# ----> 1 list_of_scores = exp.perform_exp()
#
# /home/taewook/workspace/semantic_binning/experiment.py in perform_exp(self)
#      63
#      64         for n_init_bins in self.n_init_bins_list:
# ---> 65             sb_X = self.semantic_binning.fit_transform(self.data, n_init_bins)
#      66             sb_scores = self._get_classification_score(sb_X)
#      67             list_of_scores.append(('sb_{}'.format(n_init_bins), sb_scores, sb_X.shape[1]-n_cat_dummy_var))
#
# /home/taewook/workspace/semantic_binning/semantic_binning.py in fit_transform(self, data, n_init_bins)
#      39
#      40     def fit_transform(self, data, n_init_bins=20):
# ---> 41         self.fit(data, n_init_bins)
#      42         return self.transform(data)
#      43
#
# /home/taewook/workspace/semantic_binning/semantic_binning.py in fit(self, data, n_init_bins)
#      29                                                weight_decay=self.weight_decay,
#      30                                                lr=self.lr,
# ---> 31                                                verbose=self.verbose)
#      32
#      33         self._bin_merger = BinMerger(self.bin_embedder.embedding_by_column)
#
# /home/taewook/workspace/semantic_binning/embed_bins.py in learn_bin_embeddings(self, dummy_coded_data, var_dict, embedding_dim, lr, n_epoch, weight_decay, batch_size, verbose)
#     112             if ((it+1) % n_iter_per_epoch == 0):
#     113
# --> 114                 num_bins, scores = self._get_current_cluster(dummy_coded_data, var_dict)
#     115                 curr_score = np.mean(scores)
#     116
#
# /home/taewook/workspace/semantic_binning/embed_bins.py in _get_current_cluster(self, dummy_coded_data, var_dict)
#      44         scores = []
#      45         for var in var_dict['numerical_vars']:
# ---> 46             merged_bins, score = bin_merger._merge_bins(var, return_score=True)
#      47             num_bins.append(len(merged_bins))
#      48             scores.append(score)
#
# /home/taewook/workspace/semantic_binning/merge_bins.py in _merge_bins(self, variable, return_score)
#      90         cols, dist_matrix = self._get_cols_and_pairwise_dist_btw_embeddings(variable)
#      91         if return_score:
# ---> 92             cluster_label, score = self._clustering_embeddings(dist_matrix, return_score=True)
#      93         else:
#      94             cluster_label = self._clustering_embeddings(dist_matrix)
#
# /home/taewook/workspace/semantic_binning/merge_bins.py in _clustering_embeddings(self, dist_matrix, return_score)
#      49
#      50         # Clustering with Optimal Number of Cluster
# ---> 51         best_n = np.argmax(scores) + 2
#      52         best_score = np.max(scores)
#      53
#
# /home/taewook/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in argmax(a, axis, out)
#     961
#     962     """
# --> 963     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#     964
#     965
#
# /home/taewook/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      65     # a downstream library like 'pandas'.
#      66     except (AttributeError, TypeError):
# ---> 67         return _wrapit(obj, method, *args, **kwds)
#      68
#      69
#
# /home/taewook/anaconda3/lib/python3.6/site-packages/numpy/core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      45     except AttributeError:
#      46         wrap = None
# ---> 47     result = getattr(asarray(obj), method)(*args, **kwds)
#      48     if wrap:
#      49         if not isinstance(result, mu.ndarray):
#
# ValueError: attempt to get argmax of an empty sequence

# %%
result = exp.print_scores(list_of_scores)

# %%
result.sort_values(by='n_disc_cols', ascending=True)

# %%
sb.plot_pairwise_distance_between_bins('A2')

# %%
sb.plot_pairwise_distance_between_bins('A3')

# %%
sb.plot_pairwise_distance_between_bins('A8')

# %%
sb.plot_pairwise_distance_between_bins('A11')

# %%
sb.plot_pairwise_distance_between_bins('A14')

# %%
sb.plot_pairwise_distance_between_bins('A15')

# %%
for var, bins in sb.bins_by_var.items():
    print(var)
    print(bins['bins'])
# Out:
# A2
# ['(13.749, 26.319]', '(26.319, 44.33]', '(44.33, 80.25]']
# A3
# ['(-0.001, 1.25]', '(1.25, 3.75]', '(3.75, 6.5]', '(6.5, 28.0]']
# A8
# ['(-0.001, 0.085]', '(0.085, 0.665]', '(0.665, 2.392]', '(2.392, 28.5]']
# A11
# ['(-0.001, 1.0]', '(1.0, 2.0]', '(2.0, 67.0]']
# A14
# ['(-0.001, 80.0]', '(80.0, 120.0]', '(120.0, 240.0]', '(240.0, 2000.0]']
# A15
# ['(-0.001, 1.0]', '(1.0, 300.0]', '(300.0, 100000.0]']
