# %%
from experiment import Experiment
import torch
torch.manual_seed(2)
# %matplotlib inline

# %%
var_dict = dict(
    categorical_vars = ['Work_accident', 'promotion_last_5years', 'sales', 
                        'salary'],
    numerical_vars = ['satisfaction_level', 'last_evaluation', 'average_montly_hours'
                     ,'number_project','time_spend_company'],
    class_var = 'left'
)

# %%
exp = Experiment('data/HR_comma_sep.csv', 
                 var_dict,
                 embedding_dim=8,
                 lr=0.001,
                 batch_size=1024,
                 inter_bin_distance_penalty=0.0,
                 n_epoch=100,
                 verbose=True,
                 n_bins_range=range(2,21),
                 n_init_bins_list=[5,10,15,20,30])

# %%
from data_handler import DataHandler
from semantic_binning import SemanticBinning
handler = DataHandler(exp.data, exp.var_dict)

# %%
sb = SemanticBinning(handler.var_dict, embedding_dim=8, batch_size=1024, 
                     n_epoch=20, lr=0.001, weight_decay=0.0,
                     inter_bin_distance_penalty=0.3, verbose=True)

# %%
sb.fit(exp.data, n_init_bins=30)
# Out:
# >>> Epoch = 1, Loss = 3.0075149536132812
# [25, 14, 19, 3, 4]
# >>> Epoch = 2, Loss = 2.627488136291504
# [22, 24, 18, 3, 4]
# >>> Epoch = 3, Loss = 2.2782275676727295
# [21, 21, 18, 3, 4]
# >>> Epoch = 4, Loss = 1.9815119504928589
# [18, 20, 8, 2, 2]
# >>> Epoch = 5, Loss = 1.725246548652649
# [19, 21, 13, 2, 2]
# >>> Epoch = 6, Loss = 1.4843192100524902
# [14, 16, 11, 2, 2]
# >>> Epoch = 7, Loss = 1.29722261428833
# [13, 11, 11, 2, 2]
# >>> Epoch = 8, Loss = 1.1178702116012573
# [13, 23, 16, 3, 2]
# >>> Epoch = 9, Loss = 0.961950421333313
# [5, 21, 14, 3, 2]
# >>> Epoch = 10, Loss = 0.8318837285041809
# [5, 19, 12, 3, 2]
# >>> Epoch = 11, Loss = 0.7222493886947632
# [5, 17, 13, 3, 2]
# >>> Epoch = 12, Loss = 0.6365296840667725
# [5, 15, 13, 3, 2]
# >>> Epoch = 13, Loss = 0.5600442886352539
# [10, 13, 11, 3, 2]
# >>> Epoch = 14, Loss = 0.49687260389328003
# [12, 13, 9, 3, 2]
# >>> Epoch = 15, Loss = 0.4456758499145508
# [12, 13, 9, 3, 2]
# >>> Epoch = 16, Loss = 0.4036989212036133
# [12, 13, 8, 2, 2]
# >>> Epoch = 17, Loss = 0.37097254395484924
# [12, 13, 9, 2, 2]
# >>> Epoch = 18, Loss = 0.3404202461242676
# [10, 9, 9, 2, 2]
# >>> Epoch = 19, Loss = 0.3153306245803833
# [9, 8, 9, 2, 2]
# >>> Epoch = 20, Loss = 0.2922615110874176
# [8, 8, 9, 2, 2]
# Learning Embedding Finished!

# %%
sb.bins_by_var['satisfaction_level']['bins']
# Out:
# ['(0.089, 0.37]',
#  '(0.37, 0.43]',
#  '(0.43, 0.62]',
#  '(0.62, 0.7]',
#  '(0.7, 0.72]',
#  '(0.72, 0.85]',
#  '(0.85, 0.87]',
#  '(0.87, 1.0]']

# %%
sb.plot_pairwise_distance_between_bins('satisfaction_level')

# %%
sb.bins_by_var['last_evaluation']['bins']
# Out:
# ['(0.359, 0.52]',
#  '(0.52, 0.59]',
#  '(0.59, 0.61]',
#  '(0.61, 0.7]',
#  '(0.7, 0.76]',
#  '(0.76, 0.86]',
#  '(0.86, 0.89]',
#  '(0.89, 1.0]']

# %%
sb.plot_pairwise_distance_between_bins('last_evaluation')

# %%
sb.bins_by_var['average_montly_hours']['bins']
# Out:
# ['(95.999, 146.0]',
#  '(146.0, 162.0]',
#  '(162.0, 168.0]',
#  '(168.0, 207.0]',
#  '(207.0, 232.0]',
#  '(232.0, 253.0]',
#  '(253.0, 262.0]',
#  '(262.0, 267.0]',
#  '(267.0, 310.0]']

# %%
sb.plot_pairwise_distance_between_bins('average_montly_hours')

# %%
sb.bins_by_var['number_project']['bins']
# Out:
# ['(1.999, 4.0]', '(4.0, 7.0]']

# %%
sb.plot_pairwise_distance_between_bins('number_project')

# %%
sb.bins_by_var['time_spend_company']['bins']
# Out:
# ['(1.999, 6.0]', '(6.0, 10.0]']

# %%
sb.plot_pairwise_distance_between_bins('time_spend_company')

# %% [markdown]
# # Bin 개수가 적은 경우, 다른 변수에 비해 훨씬 더 많이 update되어서 먼저 찌그러져버림..
